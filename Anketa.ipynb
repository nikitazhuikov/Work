# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import polars as pl
import csv

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

df=pd.read_csv('C:/Users/a.golub/Desktop/Anketa.csv', on_bad_lines='warn', sep=';')
df.shape
# Out:
# (1145765, 29)

# %%
df = df[df.columns[1:29]]

# %%
df = df.rename(columns={'Регион':'Region', 'Календарный_год': 'year', 'Период': 'month', 'Населенный_пункт':'location',
                        'Дата_проведения_опроса_в_формате_дд_мм_гггг':'date', 'Номер_респондента':'Resp_number',
                        '16':'accessibility', '17':'problems_with_home_call', '18':'lab_and_diag_services', '19':'disabled_persons_facil',
                        'Возраст':'Age', 'Удовлетворенность_доступностью_лекарств':'Drugs_availability'})
df=df.drop(columns=['open_question_1', 'open_question_2'], axis=1)
df
# Out:
#                                 Region  year   month   gender poselenie                                              location                  org_type            last_visit  zapis  ozhid  near_cab  comfort  attitude  explain  expect  loyalty  gen_sat                     date  Resp_number        problems_with_home_call lab_and_diag_services disabled_persons_facil  accessibility    Age problem_solved  Drugs_availability
# 0                Ленинградская область  2022  Август  Мужской      Село   Ленинградская обл., Всеволожский р-н., г. Сертолово  Только в государственных  менее 1 мес. назад\t  5.000  4.000     4.000    4.000     3.000    4.000   4.000    3.000    4.000  2022-08-15 00:00:00.000        1.000  Не пользовался данной услугой  Затрудняюсь ответить   Затрудняюсь ответить          4.000 19.000            NaN                 NaN
# ...
